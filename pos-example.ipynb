# %%
import pickle
import re
import pandas as pd 
from pos_german import ClassifierBasedGermanTagger
import nltk.data

# %%
def raw_tagger(tagger, text):
    sentences = sent_detector.tokenize(text)
    return [tagger.tag(re.findall('(\w+)', sentence)) for sentence in sentences]

# %%
dir = '/Users/juliusstahnke/Documents/HTW/Analytics/Analytics/Aufgabe4/games/'
games = pd.read_json(dir + 'games.json', orient='records', encoding='utf8')

# %%
path = '/Users/juliusstahnke/Documents/HTW/Analytics/Analytics/Aufgabe4/'
filename = 'classifier-based-german-pos-tagger.pickle'
with open(path + filename, 'rb') as f:
    tagger = pickle.load(f)

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/juliusstahnke/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
sent_detector = nltk.data.load('tokenizers/punkt/german.pickle')

# %%
example = games.iloc[0:9].content_text
example
# Out:
# 0                       Beschts spiu woni je ha gspiut
# 1                           Best Game ever Kappa kappa
# 2    Total verbuggtes Game, komme daher auch nicht ...
# 3    leider ist die grafic für den absoluter mist u...
# 4    Bei „Dust: An Elysian Tail“ handelt es sich um...
# 5    Dieses Spiel ist kurz gesagt der schlimmste Dr...
# 6    Update: Das Spiel ist jetzt schon seit einigen...
# 7                                                  ...
# 8    Ich bin nun wirklich kein Fan von "Autospielen...
# Name: content_text, dtype: object

# %%
test = [raw_tagger(tagger, a) for a in example]
#testAdj = [ b for b in test if a[0] for a in test[b] if a[1] == 'APPR']
#[a[0][1] for a in test[1]]
#[a for a in test[1] if a[1] == 'ADJD']
test
[[1 if Type == 'ADJD'] in ]
# Out:
# [[[('Beschts', 'NE'),
#    ('spiu', 'VMFIN'),
#    ('woni', 'VAINF'),
#    ('je', 'ADV'),
#    ('ha', 'ADJD'),
#    ('gspiut', 'VVPP')]],
#  [[('Best', 'NE'),
#    ('Game', 'NE'),
#    ('ever', 'ADJD'),
#    ('Kappa', 'TRUNC'),
#    ('kappa', 'VMINF')]],
#  [[('Total', 'NE'),
#    ('verbuggtes', 'ADJA'),
#    ('Game', 'NE'),
#    ('komme', 'VVFIN'),
#    ('daher', 'PROAV'),
#    ('auch', 'ADV'),
#    ('nicht', 'PTKNEG'),
#    ('weiter', 'ADV'),
#    ('im', 'APPRART'),
#    ('Spiel', 'NN')],
#   [('Updates', 'NE'),
#    ('kommen', 'VVFIN'),
#    ('zu', 'PTKZU'),
#    ('langsam', 'ADJD'),
#    ('raus', 'PTKVZ')],
#   [('Haben', 'VAFIN'),
#    ('die', 'ART'),
#    ('Entwickler', 'NN'),
#    ('das', 'ART'),
#    ('Spiel', 'NN'),
#    ('schon', 'ADV'),
#    ('aufgegeben', 'VVPP')],
#   [('Seit', 'APPR'),
#    ('X2', 'NE'),
#    ('geht', 'VVFIN'),
#    ('es', 'PPER'),
#    ('abwärts', 'ADV'),
#    ('man', 'PIS'),
#    ('hat', 'VAFIN'),
#    ('sich', 'PRF'),
#    ('zwar', 'ADV'),
# ...
